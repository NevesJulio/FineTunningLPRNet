# %%
import os
import glob
import random
import string

import numpy as np
import pandas as pd

from PIL import Image

import torch
import torch.nn as nn
import torch.optim as optim

from torch.utils.data import Dataset, DataLoader
from torchvision import transforms

from tqdm import tqdm

# Para visualização (opcional, mas útil)
import matplotlib.pyplot as plt

# Evitar warnings chatos
import warnings
warnings.filterwarnings("ignore")
# Out:
# Running cells with 'Python 3.10.11' requires the ipykernel package.
#
# <a href='command:jupyter.createPythonEnvAndSelectController'>Create a Python Environment</a> with the required packages.
#
# Or install 'ipykernel' using the command: 'c:/Users/Júlio/AppData/Local/Programs/Python/Python310/python.exe -m pip install ipykernel -U --user --force-reinstall'
